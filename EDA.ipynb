# %% [markdown]
# <a href="https://colab.research.google.com/github/manjunathsirur1994/DataCleaning-EDA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/content/world_population.csv')
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country/Territory               object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                       int64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           234.00           234.00           234.00
# mean  117.50      34074414.71      33501070.95      31729956.24
# std    67.69     136766424.80     135589876.92     130404992.75
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        415284.50        404676.00
# 50%   117.50       5559944.50       5493074.50       5307400.00
# 75%   175.75      22476504.75      21447979.50      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           234.00           234.00           234.00           234.00
# mean       29845235.03      26269468.82      22710220.79      18984616.97
# std       124218487.63     111698206.72      97832173.35      81785186.08
# min             596.00           651.00           700.00           733.00
# ...

# %%
# df.isnull().sum()
df.isna().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country/Territory              234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by='2022 Population').head()
# Out:
#      Rank CCA3 Country/Territory       Capital      Continent  \
# 226   234  VAT      Vatican City  Vatican City         Europe
# 209   233  TKL           Tokelau      Nukunonu        Oceania
# 150   232  NIU              Niue         Alofi        Oceania
# 64    231  FLK  Falkland Islands       Stanley  South America
# 137   230  MSR        Montserrat        Brades  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226              510              520              564              596
# 209             1871             1827             1454             1367
# 150             1934             1942             1847             1812
# 64              3780             3747             3408             3187
# 137             4390             4500             5059             4938
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 226              651              700              733              752
# ...

# %%
df.sort_values(by='2022 Population', ascending=False).head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
df.sort_values(by='World Population Percentage', ascending=False).head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
df.select_dtypes(exclude='object').corr()
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.34             0.99             0.99
# 1980 Population             -0.34             0.98             0.98
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.select_dtypes(exclude='object').corr(), annot=True);

# %%
num_cols = list(df.select_dtypes(exclude='object').columns)
num_cols.append('Continent')
num_cols
# Out:
# ['Rank',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population',
#  '2010 Population',
#  '2000 Population',
#  '1990 Population',
#  '1980 Population',
#  '1970 Population',
#  'Area (km²)',
#  'Density (per km²)',
#  'Growth Rate',
#  'World Population Percentage',
#  'Continent']

# %%
df[num_cols].groupby('Continent').mean()
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25030367.23      23871435.26      21071972.67
# Asia           77.56      94427665.48      93261730.70      89165003.64
# Europe        124.50      14862950.76      14915843.92      14830712.16
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       1958198.00       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa             18512773.19      14367474.25      11195625.07
# Asia               84400826.54      74701792.08      64211271.54
# Europe             14712278.68      14521868.46      14406415.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
# ...

# %%
df[df['Continent'].str.contains('Oceania')]
# Out:
#      Rank CCA3         Country/Territory       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df[num_cols].groupby('Continent').mean().sort_values(by='2022 Population', ascending=False)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      94427665.48      93261730.70      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25030367.23      23871435.26      21071972.67
# North America 160.93      15007403.40      14855914.82      14259596.25
# Europe        124.50      14862950.76      14915843.92      14830712.16
# Oceania       188.52       1958198.00       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               84400826.54      74701792.08      64211271.54
# South America      28077017.86      24973877.29      21224743.93
# Africa             18512773.19      14367474.25      11195625.07
# North America      13568016.28      12151739.60      10531660.62
# Europe             14712278.68      14521868.46      14406415.94
# ...

# %%
df[num_cols].groupby('Continent').mean().sort_values(by='2022 Population', ascending=False).plot();

# %%
plt.figure(figsize=(12,6))
df[num_cols].groupby('Continent').mean().sort_values(by='2022 Population', ascending=False).T.plot();

# %%
df[df.columns[4:10]].groupby('Continent').mean().T.plot()
# Out:
# <Axes: >

# %%
columns = []
for x in range(12,3,-1):
  columns.append(df.columns[x])
columns
# Out:
# ['1970 Population',
#  '1980 Population',
#  '1990 Population',
#  '2000 Population',
#  '2010 Population',
#  '2015 Population',
#  '2020 Population',
#  '2022 Population',
#  'Continent']

# %%
df[columns].groupby('Continent').mean()
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Africa              6411304.35       8448006.61      11195625.07
# Asia               42898125.80      52706684.56      64211271.54
# Europe             13118479.82      13850543.18      14406415.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
# South America      13781939.71      17270643.29      21224743.93
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Africa             14367474.25      18512773.19      21071972.67
# Asia               74701792.08      84400826.54      89165003.64
# Europe             14521868.46      14712278.68      14830712.16
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
# South America      24973877.29      28077017.86      29509599.71
#
# ...

# %%
df[columns].groupby('Continent').mean().T.plot(figsize=(20, 6));

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
find_this = 'Funafuti'
found = df.applymap(lambda x: x==find_this)
df.loc[found.any(axis=1)]
# Out:
# <ipython-input-56-3f7eca6ac25c>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   found = df.applymap(lambda x: x==find_this)
#      Rank CCA3 Country/Territory   Capital Continent  2022 Population  \
# 216   227  TUV            Tuvalu  Funafuti   Oceania            11312
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 216            11069            10877            10550             9638
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 216             9182             7731             5814          26
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 216             435.08         1.01                         0.00
